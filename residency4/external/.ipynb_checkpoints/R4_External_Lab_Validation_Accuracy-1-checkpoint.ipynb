# %%
# Import important library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Q1 Read the input file and check the data dimension

# %%
# You can access from https://www.kaggle.com/uciml/german-credit
#Read input file and understand the data
# "default" is my dependent variable

# %%
credit_df = pd.read_csv("german_credit.csv")

# %%
# Lets build a Ensemble model but need to modify the dataset first
credit_df.shape
# Out:
# (1000, 21)

# %%
credit_df.describe().T
# Out:
#                              count      mean          std    min     25%  \
# default                     1000.0     0.300     0.458487    0.0     0.0
# duration_in_month           1000.0    20.903    12.058814    4.0    12.0
# credit_amount               1000.0  3271.258  2822.736876  250.0  1365.5
# installment_as_income_perc  1000.0     2.973     1.118715    1.0     2.0
# present_res_since           1000.0     2.845     1.103718    1.0     2.0
# age                         1000.0    35.546    11.375469   19.0    27.0
# credits_this_bank           1000.0     1.407     0.577654    1.0     1.0
# people_under_maintenance    1000.0     1.155     0.362086    1.0     1.0
#
#                                50%      75%      max
# default                        0.0     1.00      1.0
# duration_in_month             18.0    24.00     72.0
# credit_amount               2319.5  3972.25  18424.0
# installment_as_income_perc     3.0     4.00      4.0
# ...

# %%
credit_df.dtypes
# Out:
# default                        int64
# account_check_status          object
# duration_in_month              int64
# credit_history                object
# purpose                       object
# credit_amount                  int64
# savings                       object
# present_emp_since             object
# installment_as_income_perc     int64
# personal_status_sex           object
# other_debtors                 object
# present_res_since              int64
# property                      object
# age                            int64
# other_installment_plans       object
# housing                       object
# credits_this_bank              int64
# job                           object
# people_under_maintenance       int64
# telephone                     object
# foreign_worker                object
# dtype: object

# %% [markdown]
# ### Q2.Prepare the model data by converting non-numeric to dummy ( 1 Marks)
# ##### Hint: Use get_dummies

# %%
# Print Shape of model data
credit_df.shape
# Out:
# (1000, 21)

# %%
credit_df.head()
# Out:
#    default account_check_status  duration_in_month  \
# 0        0               < 0 DM                  6
# 1        1    0 <= ... < 200 DM                 48
# 2        0  no checking account                 12
# 3        0               < 0 DM                 42
# 4        1               < 0 DM                 24
#
#                                       credit_history  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#                         purpose  credit_amount                      savings  \
# 0           domestic appliances           1169  unknown/ no savings account
# 1           domestic appliances           5951                 ... < 100 DM
# 2  (vacation - does not exist?)           2096                 ... < 100 DM
# ...

# %%
credit_df = pd.get_dummies(credit_df, columns=['account_check_status','present_emp_since','other_debtors','credit_history','purpose','savings','personal_status_sex','property','other_installment_plans','housing','job','telephone','foreign_worker'])

# %%
#credit_df = pd.get_dummies(credit_df, columns=['housing_own'])
credit_df.columns
# Out:
# Index(['default', 'duration_in_month', 'credit_amount',
#        'installment_as_income_perc', 'present_res_since', 'age',
#        'credits_this_bank', 'people_under_maintenance',
#        'account_check_status_0 <= ... < 200 DM', 'account_check_status_< 0 DM',
#        'account_check_status_>= 200 DM / salary assignments for at least 1 year',
#        'account_check_status_no checking account',
#        'present_emp_since_.. >= 7 years', 'present_emp_since_... < 1 year ',
#        'present_emp_since_1 <= ... < 4 years',
#        'present_emp_since_4 <= ... < 7 years', 'present_emp_since_unemployed',
#        'other_debtors_co-applicant', 'other_debtors_guarantor',
#        'other_debtors_none',
#        'credit_history_all credits at this bank paid back duly',
#        'credit_history_critical account/ other credits existing (not at this bank)',
#        'credit_history_delay in paying off in the past',
#        'credit_history_existing credits paid back duly till now',
# ...

# %% [markdown]
# ### Check for highly correlated variables but don't required any treatment for this use case

# %%
credit_df.corr().T
# Out:
#                                                      default  \
# default                                             1.000000
# duration_in_month                                   0.214927
# credit_amount                                       0.154739
# installment_as_income_perc                          0.072404
# present_res_since                                   0.002967
# age                                                -0.091127
# credits_this_bank                                  -0.045732
# people_under_maintenance                           -0.003015
# account_check_status_0 <= ... < 200 DM              0.119581
# account_check_status_< 0 DM                         0.258333
# account_check_status_>= 200 DM / salary assignm... -0.044009
# account_check_status_no checking account           -0.322436
# present_emp_since_.. >= 7 years                    -0.059733
# present_emp_since_... < 1 year                      0.106397
# ...

# %% [markdown]
# ### Drop the original variables which are converted to dummy

# %%
credit_df.columns
# Out:
# Index(['default', 'duration_in_month', 'credit_amount',
#        'installment_as_income_perc', 'present_res_since', 'age',
#        'credits_this_bank', 'people_under_maintenance',
#        'account_check_status_0 <= ... < 200 DM', 'account_check_status_< 0 DM',
#        'account_check_status_>= 200 DM / salary assignments for at least 1 year',
#        'account_check_status_no checking account',
#        'present_emp_since_.. >= 7 years', 'present_emp_since_... < 1 year ',
#        'present_emp_since_1 <= ... < 4 years',
#        'present_emp_since_4 <= ... < 7 years', 'present_emp_since_unemployed',
#        'other_debtors_co-applicant', 'other_debtors_guarantor',
#        'other_debtors_none',
#        'credit_history_all credits at this bank paid back duly',
#        'credit_history_critical account/ other credits existing (not at this bank)',
#        'credit_history_delay in paying off in the past',
#        'credit_history_existing credits paid back duly till now',
# ...

# %%
#credit_df=credit_df.drop(columns=['account_check_status','present_emp_since','other_debtors','credit_history','purpose','savings','personal_status_sex','property','other_installment_plans','housing','job','telephone','foreign_worker'])
credit_df.head()
# Out:
#    default  duration_in_month  credit_amount  installment_as_income_perc  \
# 0        0                  6           1169                           4
# 1        1                 48           5951                           2
# 2        0                 12           2096                           2
# 3        0                 42           7882                           2
# 4        1                 24           4870                           3
#
#    present_res_since  age  credits_this_bank  people_under_maintenance  \
# 0                  4   67                  2                         1
# 1                  2   22                  1                         1
# 2                  3   49                  1                         2
# 3                  4   45                  1                         2
# 4                  4   53                  2                         2
#
#    account_check_status_0 <= ... < 200 DM  account_check_status_< 0 DM  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_features = credit_df.copy()
col_names = ['credit_amount']
features = scaled_features[col_names]
scaler = StandardScaler().fit(features.values)
features = scaler.transform(features.values)

scaled_features[col_names] = features

scaled_features.head()
# Out:
#    default  duration_in_month  credit_amount  installment_as_income_perc  \
# 0        0                  6      -0.745131                           4
# 1        1                 48       0.949817                           2
# 2        0                 12      -0.416562                           2
# 3        0                 42       1.634247                           2
# 4        1                 24       0.566664                           3
#
#    present_res_since  age  credits_this_bank  people_under_maintenance  \
# 0                  4   67                  2                         1
# 1                  2   22                  1                         1
# 2                  3   49                  1                         2
# 3                  4   45                  1                         2
# 4                  4   53                  2                         2
#
#    account_check_status_0 <= ... < 200 DM  account_check_status_< 0 DM  \
# ...

# %% [markdown]
# ### Q3 Split Train/Test data 70:30 ratio( 1 Marks)
# ##### Hint:from sklearn.model_selection import train_test_split

# %%
X=scaled_features.drop(['default'],axis=1)

# %%
y=scaled_features['default']

# %%
X.columns
# Out:
# Index(['duration_in_month', 'credit_amount', 'installment_as_income_perc',
#        'present_res_since', 'age', 'credits_this_bank',
#        'people_under_maintenance', 'account_check_status_0 <= ... < 200 DM',
#        'account_check_status_< 0 DM',
#        'account_check_status_>= 200 DM / salary assignments for at least 1 year',
#        'account_check_status_no checking account',
#        'present_emp_since_.. >= 7 years', 'present_emp_since_... < 1 year ',
#        'present_emp_since_1 <= ... < 4 years',
#        'present_emp_since_4 <= ... < 7 years', 'present_emp_since_unemployed',
#        'other_debtors_co-applicant', 'other_debtors_guarantor',
#        'other_debtors_none',
#        'credit_history_all credits at this bank paid back duly',
#        'credit_history_critical account/ other credits existing (not at this bank)',
#        'credit_history_delay in paying off in the past',
#        'credit_history_existing credits paid back duly till now',
# ...

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# Name: default, dtype: int64

# %%
#credit_df = pd.get_dummies(credit_df, columns=['telephone'])
#credit_df=credit_df.drop(columns=['telephone'])
scaled_features.head()
# Out:
#    default  duration_in_month  credit_amount  installment_as_income_perc  \
# 0        0                  6      -0.745131                           4
# 1        1                 48       0.949817                           2
# 2        0                 12      -0.416562                           2
# 3        0                 42       1.634247                           2
# 4        1                 24       0.566664                           3
#
#    present_res_since  age  credits_this_bank  people_under_maintenance  \
# 0                  4   67                  2                         1
# 1                  2   22                  1                         1
# 2                  3   49                  1                         2
# 3                  4   45                  1                         2
# 4                  4   53                  2                         2
#
#    account_check_status_0 <= ... < 200 DM  account_check_status_< 0 DM  \
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.24, random_state=42)

# %% [markdown]
# ### Q4 Build Random Forest Model( 1 Marks)
# #### Hint:from sklearn.ensemble import RandomForestClassifier using n_jobs=2,n_estimators=500,criterion="entropy",random_state=9999

# %%
X_train.dtypes
# Out:
# duration_in_month                                                               int64
# credit_amount                                                                 float64
# installment_as_income_perc                                                      int64
# present_res_since                                                               int64
# age                                                                             int64
# credits_this_bank                                                               int64
# people_under_maintenance                                                        int64
# account_check_status_0 <= ... < 200 DM                                          uint8
# account_check_status_< 0 DM                                                     uint8
# account_check_status_>= 200 DM / salary assignments for at least 1 year         uint8
# account_check_status_no checking account                                        uint8
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_jobs=2,n_estimators=500,criterion="entropy",random_state=9999)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

# %% [markdown]
# ### Q5 Calculate Confusion Matrix and Accuracy score (1 Marks)
# ##### Hint: Use confusion_matrix and accuracy_score

# %%
score = clf.score(X_test, y_test)
print(score)
# Out:
# 0.7875

# %% [markdown]
# ### Q6 Show the list of the features importance( 1 Marks)

# %%
print(clf.feature_importances_)
# Out:
# [0.07234073 0.09952331 0.03572662 0.03447671 0.0848428  0.01913886
#  0.01016374 0.01703415 0.02879969 0.00770527 0.04836071 0.01417491
#  0.01412152 0.01483562 0.01302721 0.0094765  0.00493113 0.00844614
#  0.0099578  0.00945428 0.02282078 0.00897354 0.01508921 0.01160085
#  0.00867409 0.01043084 0.01902623 0.0108794  0.01556016 0.00461462
#  0.00217479 0.01268653 0.00213366 0.00096244 0.00615849 0.01772067
#  0.00811186 0.00702451 0.01242625 0.01534798 0.00558811 0.00745946
#  0.01573042 0.01305403 0.01475444 0.01637392 0.01158935 0.01326829
#  0.01537934 0.00570614 0.00783976 0.01638543 0.01072674 0.01322656
#  0.01513213 0.00217866 0.01084761 0.01406806 0.01482845 0.003371
#  0.00353749]

# %%
#credit_df['feature_imp']=clf.feature_importances_
#-*credit_df.head()

# %%
scaled_features.head()
# Out:
#    default  duration_in_month  credit_amount  installment_as_income_perc  \
# 0        0                  6      -0.745131                           4
# 1        1                 48       0.949817                           2
# 2        0                 12      -0.416562                           2
# 3        0                 42       1.634247                           2
# 4        1                 24       0.566664                           3
#
#    present_res_since  age  credits_this_bank  people_under_maintenance  \
# 0                  4   67                  2                         1
# 1                  2   22                  1                         1
# 2                  3   49                  1                         2
# 3                  4   45                  1                         2
# 4                  4   53                  2                         2
#
#    account_check_status_0 <= ... < 200 DM  account_check_status_< 0 DM  \
# ...

# %% [markdown]
# ### Q7 K-fold cross-validation( 2 Marks)
# ##### k-fold cross validation( without stratification)
# ##### Usually k is set as 10-20 in practical settings, depends on data set size

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
# Use below values
num_folds = 10
seed = 77
#Create a Gaussian Classifier
clf=RandomForestClassifier(n_jobs=2,n_estimators=500,criterion="entropy",random_state=9999)
cv = KFold(n_splits=num_folds, random_state=seed, shuffle=False)

# %%
X=scaled_features.drop(['default'],axis=1)
y=scaled_features['default']

# %%
X.head()
# Out:
#    duration_in_month  credit_amount  installment_as_income_perc  \
# 0                  6      -0.745131                           4
# 1                 48       0.949817                           2
# 2                 12      -0.416562                           2
# 3                 42       1.634247                           2
# 4                 24       0.566664                           3
#
#    present_res_since  age  credits_this_bank  people_under_maintenance  \
# 0                  4   67                  2                         1
# 1                  2   22                  1                         1
# 2                  3   49                  1                         2
# 3                  4   45                  1                         2
# 4                  4   53                  2                         2
#
#    account_check_status_0 <= ... < 200 DM  account_check_status_< 0 DM  \
# 0                                       0                            1
# ...

# %%
#Validate the Random Forest model build above using k fold

# %%
scores = cross_val_score(clf, X, y, cv=10)
print(scores)

# %%
#predictions=cross_val_predict(clf, X, y, cv=10)

# %%
#Calculate Mean score

# %%
print(np.mean(scores))
# Out:
# 0.772

# %%
# Calculate score standard deviation using std()

# %%
scores.std()
# Out:
# 0.03091924966748062

# %% [markdown]
# # Q8 Print the confusion matrix( 1 Marks)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
y_pred = cross_val_predict(clf, X, y, cv=10)
conf_mat = confusion_matrix(y, y_pred)
print(conf_mat)
# Out:
# [[653  47]
#  [181 119]]

# %% [markdown]
# # Q9.Classification accuracy:
# percentage of correct predictions and Calculate sensitivity (or True Positive Rate or Recall) and Precision.
# ( 1 Marks)

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.77 (+/- 0.06)

# %%
from sklearn.metrics import classification_report
target_names = ['Yes','No']
print(classification_report(y, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#          Yes       0.78      0.93      0.85       700
#           No       0.72      0.40      0.51       300
#
#    micro avg       0.77      0.77      0.77      1000
#    macro avg       0.75      0.66      0.68      1000
# weighted avg       0.76      0.77      0.75      1000

# %% [markdown]
# # Q10.Plot Receiver Operating Characteristic (ROC) Curves( 1 Marks)

# %%
#Hint: Use roc_curve

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y, probs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-1f3731819a5a> in <module>()
#       2 from sklearn.metrics import roc_auc_score
#       3 # calculate roc curve
# ----> 4 fpr, tpr, thresholds = roc_curve(y, probs)
#
# NameError: name 'probs' is not defined

# %% [markdown]
# ROC curve can help you to choose a threshold that balances sensitivity and specificity in a way that makes sense for your particular context

# %% [markdown]
# # Q11. Calculate AUC(the percentage of the ROC plot that is underneath the curve) - optional

# %% [markdown]
# ### Bootstrapping ( Bonus)
# ##### Given a dataset of size n, a bootstrap sample is created by sampling n instances uniformly from the data (with/without replacement)
# ##### Create a model with each bootstrap sample and validate it with the test set
# ##### Final result is calculated by averaging the accuracy of models

# %%
# Number of iterations for bootstrapping
bootstrap_iteration = 10
accuracy = []

# %%
from sklearn.utils import resample
from sklearn.metrics import accuracy_score

for i in range(bootstrap_iteration):
    X_, y_ = resample(X_train, y_train)
    rfm.fit(X_, y_)
    y_pred = rfm.predict(X_test)
    
    acc = accuracy_score(y_pred, y_test)
    accuracy.append(acc)

# %%
accuracy = np.array(accuracy)
print('Accuracy Score')
print('Avearge: ', accuracy.mean())
print('Standard deviation: ', accuracy.std())
